# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from report_config import ReportConfig

# %%
reviews_df = pd.read_csv("./glassdoor_reviews_predicted.csv")

# %%
reviews_df["sentiment"] = reviews_df["sentiment"].apply(lambda x: 2 if x == -1 else x)

# %%
reviews_df["predicted_sentiment_label"] = reviews_df["predicted_sentiment"].map(
    ReportConfig.SENTIMENT_DICT
)

# %%
mean_reviews_count = len(reviews_df) / len(reviews_df["company"].unique())
mean_reviews_count
# Out:
# 115.0909090909091

# %%
review_counts = reviews_df.groupby("company")["review_id"].count()
sorted_counts = review_counts.sort_values()
median = sorted_counts.median()
median
# Out:
# 42.0

# %%
sorted_counts
# Out:
# company
# Original Soluções Tecnológicas                                 2
# Intelecto Sistemas                                             6
# Datweb                                                        12
# MTI - Empresa Mato-grossense de Tecnologia da Informação      14
# Puma Sistemas                                                 16
# Ganso Sistemas                                                30
# Coplan Consultoria e Planejamento                             32
# Tecnomapas                                                    34
# Fundação Uniselva                                             36
# Liberali                                                      36
# MOVERE (Brazil)                                               40
# Totem Treinamento e Consultoria em TI                         44
# Log, Lab. Inteligência Digital                                50
# NBS Informática                                               54
# Eco Centauro                                                  74
# Agenda Assessoria                                             96
# Abaco Tecnologia de Informação Ltda                          110
# DSS Tecnologia                                               122
# Redeflex                                                     190
# Grupo Bom Futuro                                             324
# Cigam Software Corporativo                                   354
# Amaggi                                                       856
# Name: review_id, dtype: int64

# %% [markdown]
# # Top 5 positive and negative companies

# %%
reviews_df = reviews_df.sort_values(by="predicted_sentiment").reset_index()

# %%
reviews_df.head(2)
# Out:
#    index  review_id                     company            employee_role  \
# 0   1265   64925288  Cigam Software Corporativo               Estagiário
# 1   1841   75733214            Grupo Bom Futuro  Assistente de pagadoria
#
#         employee_detail                    review_text review_date  \
# 0  Funcionário(a) atual  não encontrei nenhum até hoje  2022-05-31
# 1  Funcionário(a) atual   Não tem contras nada a dizer  2023-04-22
#
#    star_rating  sentiment  annotated  predicted_sentiment  \
# 0          5.0          0          1                    0
# 1          5.0          0          1                    0
#
#   predicted_sentiment_label
# 0                    Neutro
# 1                    Neutro

# %% [markdown]
# Create a column to order predicted_sentiment as `positive`, `negative` and `neutral` instead of `neutral`, `positive` and `negative`

# %%
conditions = [
    (reviews_df["predicted_sentiment"] == 0),
    (reviews_df["predicted_sentiment"] == 1),
    (reviews_df["predicted_sentiment"] == 2),
]

values = [3, 1, 2]

reviews_df["predicted_sentiment_plot"] = np.select(conditions, values)

# %%
reviews_df.head(2)
# Out:
#    index  review_id                     company            employee_role  \
# 0   1265   64925288  Cigam Software Corporativo               Estagiário
# 1   1841   75733214            Grupo Bom Futuro  Assistente de pagadoria
#
#         employee_detail                    review_text review_date  \
# 0  Funcionário(a) atual  não encontrei nenhum até hoje  2022-05-31
# 1  Funcionário(a) atual   Não tem contras nada a dizer  2023-04-22
#
#    star_rating  sentiment  annotated  predicted_sentiment  \
# 0          5.0          0          1                    0
# 1          5.0          0          1                    0
#
#   predicted_sentiment_label  predicted_sentiment_plot
# 0                    Neutro                         3
# 1                    Neutro                         3

# %%
reviews_df[reviews_df["company"].str.startswith("MTI")]["company"].count()
# Out:
# 14

# %%
sentiment_counts = (
    reviews_df.groupby(["company", "predicted_sentiment_plot"])
    .size()
    .unstack(fill_value=0)
)

sentiment_counts_reset = sentiment_counts.reset_index()
sentiment_counts_reset.columns = ["company", "1positive", "2negative", "3neutral"]

# %%
sentiment_counts
# Out:
# predicted_sentiment_plot                              1    2   3
# company
# Abaco Tecnologia de Informação Ltda                  50   50  10
# Agenda Assessoria                                    46   40  10
# Amaggi                                              438  349  69
# Cigam Software Corporativo                          176  139  39
# Coplan Consultoria e Planejamento                    15   14   3
# DSS Tecnologia                                       53   52  17
# Datweb                                                7    4   1
# Eco Centauro                                         38   28   8
# Fundação Uniselva                                    17   18   1
# Ganso Sistemas                                       16   12   2
# Grupo Bom Futuro                                    173  116  35
# Intelecto Sistemas                                    3    2   1
# Liberali                                             15   20   1
# Log, Lab. Inteligência Digital                       25   23   2
# MOVERE (Brazil)                                      18   18   4
# MTI - Empresa Mato-grossense de Tecnologia da I...    6    7   1
# NBS Informática                                      27   26   1
# Original Soluções Tecnológicas                        1    1   0
# Puma Sistemas                                         9    6   1
# Redeflex                                             87   96   7
# Tecnomapas                                           15   14   5
# Totem Treinamento e Consultoria em TI                22   17   5

# %%
# & (
#             sentiment_counts_reset["1positive"]
#             + sentiment_counts_reset["2negative"]
#             + sentiment_counts_reset["3neutral"] >= min_reviews
#         )

# %%
def get_bad_rating_companies():
    negative_greater_than_positive = sentiment_counts_reset[
        sentiment_counts_reset["2negative"] > sentiment_counts_reset["1positive"]
    ]

    negative_greater_than_positive = negative_greater_than_positive.sort_values(
        by="2negative", ascending=False
    ).reset_index()

    return list(negative_greater_than_positive["company"].values)

# %%
def get_good_rating_companies():
    positive_greater_than_negative = sentiment_counts_reset[
        sentiment_counts_reset["1positive"] > sentiment_counts_reset["2negative"]
    ]

    positive_greater_than_negative = positive_greater_than_negative.sort_values(
        by="1positive", ascending=False
    ).reset_index()

    return list(positive_greater_than_negative["company"].values)

# %%
def get_neutral_rating_companies(min_reviews=0):
    positive_equal_to_negative = sentiment_counts_reset[
        sentiment_counts_reset["1positive"] == sentiment_counts_reset["2negative"]
    ]

    return list(positive_equal_to_negative["company"].values)

# %%
bad_rating_companies = get_bad_rating_companies()
good_rating_companies = get_good_rating_companies()
neutral_rating_companies = get_neutral_rating_companies()

# %%
sentiment_by_company_count_df = (
    reviews_df.groupby(["company", "predicted_sentiment_plot"])
    .size()
    .reset_index(name="count")
)

# %%
sentiment_by_company_count_df
# Out:
#                                   company  predicted_sentiment_plot  count
# 0     Abaco Tecnologia de Informação Ltda                         1     50
# 1     Abaco Tecnologia de Informação Ltda                         2     50
# 2     Abaco Tecnologia de Informação Ltda                         3     10
# 3                       Agenda Assessoria                         1     46
# 4                       Agenda Assessoria                         2     40
# ..                                    ...                       ...    ...
# 60                             Tecnomapas                         2     14
# 61                             Tecnomapas                         3      5
# 62  Totem Treinamento e Consultoria em TI                         1     22
# 63  Totem Treinamento e Consultoria em TI                         2     17
# 64  Totem Treinamento e Consultoria em TI                         3      5
#
# [65 rows x 3 columns]

# %%
predicted_sentiment_plot_count_df = (
    reviews_df.groupby(["company", "predicted_sentiment_plot"])
    .size()
    .unstack(fill_value=0)
)

# %%
predicted_sentiment_plot_count_df
# Out:
# predicted_sentiment_plot                              1    2   3
# company
# Abaco Tecnologia de Informação Ltda                  50   50  10
# Agenda Assessoria                                    46   40  10
# Amaggi                                              438  349  69
# Cigam Software Corporativo                          176  139  39
# Coplan Consultoria e Planejamento                    15   14   3
# DSS Tecnologia                                       53   52  17
# Datweb                                                7    4   1
# Eco Centauro                                         38   28   8
# Fundação Uniselva                                    17   18   1
# Ganso Sistemas                                       16   12   2
# Grupo Bom Futuro                                    173  116  35
# Intelecto Sistemas                                    3    2   1
# Liberali                                             15   20   1
# Log, Lab. Inteligência Digital                       25   23   2
# MOVERE (Brazil)                                      18   18   4
# MTI - Empresa Mato-grossense de Tecnologia da I...    6    7   1
# NBS Informática                                      27   26   1
# Original Soluções Tecnológicas                        1    1   0
# Puma Sistemas                                         9    6   1
# Redeflex                                             87   96   7
# Tecnomapas                                           15   14   5
# Totem Treinamento e Consultoria em TI                22   17   5

# %%
predicted_sentiment_plot_count_df = predicted_sentiment_plot_count_df.reset_index()

# company_sentiment_counts_diff = (
#     predicted_sentiment_plot_count_df.groupby(["company", "predicted_sentiment_plot"])
#     .size()
#     .unstack(fill_value=0)
# )

# %%
predicted_sentiment_plot_count_df
# Out:
# predicted_sentiment_plot                                            company  \
# 0                                       Abaco Tecnologia de Informação Ltda
# 1                                                         Agenda Assessoria
# 2                                                                    Amaggi
# 3                                                Cigam Software Corporativo
# 4                                         Coplan Consultoria e Planejamento
# 5                                                            DSS Tecnologia
# 6                                                                    Datweb
# 7                                                              Eco Centauro
# 8                                                         Fundação Uniselva
# 9                                                            Ganso Sistemas
# 10                                                         Grupo Bom Futuro
# 11                                                       Intelecto Sistemas
# 12                                                                 Liberali
# 13                                           Log, Lab. Inteligência Digital
# 14                                                          MOVERE (Brazil)
# 15                        MTI - Empresa Mato-grossense de Tecnologia da ...
# 16                                                          NBS Informática
# 17                                           Original Soluções Tecnológicas
# 18                                                            Puma Sistemas
# 19                                                                 Redeflex
# 20                                                               Tecnomapas
# 21                                    Totem Treinamento e Consultoria em TI
#
# predicted_sentiment_plot    1    2   3
# 0                          50   50  10
# 1                          46   40  10
# 2                         438  349  69
# 3                         176  139  39
# 4                          15   14   3
# 5                          53   52  17
# 6                           7    4   1
# 7                          38   28   8
# 8                          17   18   1
# 9                          16   12   2
# 10                        173  116  35
# 11                          3    2   1
# 12                         15   20   1
# 13                         25   23   2
# 14                         18   18   4
# 15                          6    7   1
# 16                         27   26   1
# 17                          1    1   0
# 18                          9    6   1
# 19                         87   96   7
# 20                         15   14   5
# 21                         22   17   5

# %%
predicted_sentiment_plot_count_df.columns = [
    "company",
    "1positive",
    "2negative",
    "3neutral",
]

# %%
predicted_sentiment_plot_count_df
# Out:
#                                               company  1positive  2negative  \
# 0                 Abaco Tecnologia de Informação Ltda         50         50
# 1                                   Agenda Assessoria         46         40
# 2                                              Amaggi        438        349
# 3                          Cigam Software Corporativo        176        139
# 4                   Coplan Consultoria e Planejamento         15         14
# 5                                      DSS Tecnologia         53         52
# 6                                              Datweb          7          4
# 7                                        Eco Centauro         38         28
# 8                                   Fundação Uniselva         17         18
# 9                                      Ganso Sistemas         16         12
# 10                                   Grupo Bom Futuro        173        116
# 11                                 Intelecto Sistemas          3          2
# 12                                           Liberali         15         20
# 13                     Log, Lab. Inteligência Digital         25         23
# 14                                    MOVERE (Brazil)         18         18
# 15  MTI - Empresa Mato-grossense de Tecnologia da ...          6          7
# 16                                    NBS Informática         27         26
# 17                     Original Soluções Tecnológicas          1          1
# 18                                      Puma Sistemas          9          6
# 19                                           Redeflex         87         96
# 20                                         Tecnomapas         15         14
# 21              Totem Treinamento e Consultoria em TI         22         17
#
#     3neutral
# 0         10
# 1         10
# 2         69
# 3         39
# 4          3
# 5         17
# 6          1
# 7          8
# 8          1
# 9          2
# 10        35
# 11         1
# 12         1
# 13         2
# 14         4
# 15         1
# 16         1
# 17         0
# 18         1
# 19         7
# 20         5
# 21         5

# %%
predicted_sentiment_plot_count_df["sentiment_diff"] = (
    predicted_sentiment_plot_count_df["1positive"]
    - predicted_sentiment_plot_count_df["2negative"]
)

# %%
predicted_sentiment_plot_count_df
# Out:
#                                               company  1positive  2negative  \
# 0                 Abaco Tecnologia de Informação Ltda         50         50
# 1                                   Agenda Assessoria         46         40
# 2                                              Amaggi        438        349
# 3                          Cigam Software Corporativo        176        139
# 4                   Coplan Consultoria e Planejamento         15         14
# 5                                      DSS Tecnologia         53         52
# 6                                              Datweb          7          4
# 7                                        Eco Centauro         38         28
# 8                                   Fundação Uniselva         17         18
# 9                                      Ganso Sistemas         16         12
# 10                                   Grupo Bom Futuro        173        116
# 11                                 Intelecto Sistemas          3          2
# 12                                           Liberali         15         20
# 13                     Log, Lab. Inteligência Digital         25         23
# 14                                    MOVERE (Brazil)         18         18
# 15  MTI - Empresa Mato-grossense de Tecnologia da ...          6          7
# 16                                    NBS Informática         27         26
# 17                     Original Soluções Tecnológicas          1          1
# 18                                      Puma Sistemas          9          6
# 19                                           Redeflex         87         96
# 20                                         Tecnomapas         15         14
# 21              Totem Treinamento e Consultoria em TI         22         17
#
#     3neutral  sentiment_diff
# 0         10               0
# 1         10               6
# 2         69              89
# 3         39              37
# 4          3               1
# 5         17               1
# 6          1               3
# 7          8              10
# 8          1              -1
# 9          2               4
# 10        35              57
# 11         1               1
# 12         1              -5
# 13         2               2
# 14         4               0
# 15         1              -1
# 16         1               1
# 17         0               0
# 18         1               3
# 19         7              -9
# 20         5               1
# 21         5               5

# %%
predicted_sentiment_plot_count_df = predicted_sentiment_plot_count_df.sort_values(
    by="sentiment_diff", ascending=False
).reset_index()

# %%
predicted_sentiment_plot_count_df
# Out:
#     index                                            company  1positive  \
# 0       2                                             Amaggi        438
# 1      10                                   Grupo Bom Futuro        173
# 2       3                         Cigam Software Corporativo        176
# 3       7                                       Eco Centauro         38
# 4       1                                  Agenda Assessoria         46
# 5      21              Totem Treinamento e Consultoria em TI         22
# 6       9                                     Ganso Sistemas         16
# 7      18                                      Puma Sistemas          9
# 8       6                                             Datweb          7
# 9      13                     Log, Lab. Inteligência Digital         25
# 10     20                                         Tecnomapas         15
# 11     16                                    NBS Informática         27
# 12     11                                 Intelecto Sistemas          3
# 13      5                                     DSS Tecnologia         53
# 14      4                  Coplan Consultoria e Planejamento         15
# 15     14                                    MOVERE (Brazil)         18
# 16     17                     Original Soluções Tecnológicas          1
# 17      0                Abaco Tecnologia de Informação Ltda         50
# 18     15  MTI - Empresa Mato-grossense de Tecnologia da ...          6
# 19      8                                  Fundação Uniselva         17
# 20     12                                           Liberali         15
# 21     19                                           Redeflex         87
#
#     2negative  3neutral  sentiment_diff
# 0         349        69              89
# 1         116        35              57
# 2         139        39              37
# 3          28         8              10
# 4          40        10               6
# 5          17         5               5
# 6          12         2               4
# 7           6         1               3
# 8           4         1               3
# 9          23         2               2
# 10         14         5               1
# 11         26         1               1
# 12          2         1               1
# 13         52        17               1
# 14         14         3               1
# 15         18         4               0
# 16          1         0               0
# 17         50        10               0
# 18          7         1              -1
# 19         18         1              -1
# 20         20         1              -5
# 21         96         7              -9

# %%
company_sentiment_counts = pd.merge(
    left=sentiment_by_company_count_df,
    right=predicted_sentiment_plot_count_df,
    on="company",
    how="left",
)

# %%
company_sentiment_counts = company_sentiment_counts.sort_values(
    by="sentiment_diff", ascending=False
).reset_index()

# %%
company_sentiment_counts
# Out:
#     level_0           company  predicted_sentiment_plot  count  index  \
# 0         8            Amaggi                         3     69      2
# 1         6            Amaggi                         1    438      2
# 2         7            Amaggi                         2    349      2
# 3        30  Grupo Bom Futuro                         1    173     10
# 4        31  Grupo Bom Futuro                         2    116     10
# ..      ...               ...                       ...    ...    ...
# 60       37          Liberali                         2     20     12
# 61       36          Liberali                         1     15     12
# 62       56          Redeflex                         1     87     19
# 63       57          Redeflex                         2     96     19
# 64       58          Redeflex                         3      7     19
#
#     1positive  2negative  3neutral  sentiment_diff
# 0         438        349        69              89
# 1         438        349        69              89
# 2         438        349        69              89
# 3         173        116        35              57
# 4         173        116        35              57
# ..        ...        ...       ...             ...
# 60         15         20         1              -5
# 61         15         20         1              -5
# 62         87         96         7              -9
# 63         87         96         7              -9
# 64         87         96         7              -9
#
# [65 rows x 9 columns]

# %%
top_company_sentiment_counts = company_sentiment_counts[
    (
        company_sentiment_counts["company"].isin(good_rating_companies[:5])
        | company_sentiment_counts["company"].isin(bad_rating_companies[:5])
    )
]

# %%
top_company_sentiment_counts
# Out:
#     level_0                                            company  \
# 0         8                                             Amaggi
# 1         6                                             Amaggi
# 2         7                                             Amaggi
# 3        30                                   Grupo Bom Futuro
# 4        31                                   Grupo Bom Futuro
# 5        32                                   Grupo Bom Futuro
# 6         9                         Cigam Software Corporativo
# 7        10                         Cigam Software Corporativo
# 8        11                         Cigam Software Corporativo
# 12        5                                  Agenda Assessoria
# 13        4                                  Agenda Assessoria
# 14        3                                  Agenda Assessoria
# 34       15                                     DSS Tecnologia
# 35       16                                     DSS Tecnologia
# 36       17                                     DSS Tecnologia
# 53       46  MTI - Empresa Mato-grossense de Tecnologia da ...
# 54       45  MTI - Empresa Mato-grossense de Tecnologia da ...
# 55       24                                  Fundação Uniselva
# 56       25                                  Fundação Uniselva
# 57       26                                  Fundação Uniselva
# 58       47  MTI - Empresa Mato-grossense de Tecnologia da ...
# 59       38                                           Liberali
# 60       37                                           Liberali
# 61       36                                           Liberali
# 62       56                                           Redeflex
# 63       57                                           Redeflex
# 64       58                                           Redeflex
#
#     predicted_sentiment_plot  count  index  1positive  2negative  3neutral  \
# 0                          3     69      2        438        349        69
# 1                          1    438      2        438        349        69
# 2                          2    349      2        438        349        69
# 3                          1    173     10        173        116        35
# 4                          2    116     10        173        116        35
# 5                          3     35     10        173        116        35
# 6                          1    176      3        176        139        39
# 7                          2    139      3        176        139        39
# 8                          3     39      3        176        139        39
# 12                         3     10      1         46         40        10
# 13                         2     40      1         46         40        10
# 14                         1     46      1         46         40        10
# 34                         1     53      5         53         52        17
# 35                         2     52      5         53         52        17
# 36                         3     17      5         53         52        17
# 53                         2      7     15          6          7         1
# 54                         1      6     15          6          7         1
# 55                         1     17      8         17         18         1
# 56                         2     18      8         17         18         1
# 57                         3      1      8         17         18         1
# 58                         3      1     15          6          7         1
# 59                         3      1     12         15         20         1
# 60                         2     20     12         15         20         1
# 61                         1     15     12         15         20         1
# 62                         1     87     19         87         96         7
# 63                         2     96     19         87         96         7
# 64                         3      7     19         87         96         7
#
#     sentiment_diff
# 0               89
# 1               89
# 2               89
# 3               57
# 4               57
# 5               57
# 6               37
# 7               37
# 8               37
# 12               6
# 13               6
# 14               6
# 34               1
# 35               1
# 36               1
# 53              -1
# 54              -1
# 55              -1
# 56              -1
# 57              -1
# 58              -1
# 59              -5
# 60              -5
# 61              -5
# 62              -9
# 63              -9
# 64              -9

# %% [markdown]
# ## Barplot

# %%
# Step 2: Create the bar plot using sns.barplot
fig, ax = plt.subplots(1, figsize=(10, 8))  # Create a subplot if not already done

company_barplot = sns.barplot(
    data=top_company_sentiment_counts,
    x="count",  # y-axis for counts
    y="company",  # x-axis for companies
    hue="predicted_sentiment_plot",  # Different colors for each sentiment
    palette=[
        ReportConfig.POSITIVE_SENTIMENT_COLOR,
        ReportConfig.NEGATIVE_SENTIMENT_COLOR,
        ReportConfig.NEUTRAL_SENTIMENT_COLOR,
    ],
    ax=ax,
    width=0.9,
    orient="h",
)

# Highlight Companies
for i, label in enumerate(ax.get_yticklabels()):
    company_name = label.get_text()
    if company_name in bad_rating_companies:
        label.set_color(ReportConfig.NEGATIVE_SENTIMENT_COLOR)

for i, label in enumerate(ax.get_yticklabels()):
    company_name = label.get_text()
    if company_name in good_rating_companies:
        label.set_color(ReportConfig.POSITIVE_SENTIMENT_COLOR)

for i, label in enumerate(ax.get_yticklabels()):
    company_name = label.get_text()
    if company_name in neutral_rating_companies:
        label.set_color(ReportConfig.NEUTRAL_SENTIMENT_COLOR)

# Plot Annotates
for p in ax.patches:
    ax.annotate(
        text=f"{p.get_width():.0f}",
        xy=(p.get_width() + 10, (p.get_y() + p.get_height() / 2) + 0.02),
        ha="center",
        va="center",
        fontsize=6,
        color="black",
        xytext=(0, 0),
        textcoords="offset points",
    )

# ## Top Companies Annotates
# y_min, y_max = ax.get_ylim()
# y_position = (y_min + y_max) / 2

# x_annonate = 200
# font_size_annotate = 12
# # Top Positive Companies Annotates
# ax.annotate(
#     "Top 3 reviews positivos:",
#     xy=(x_annonate, y_position - 3),
#     fontsize=font_size_annotate,
#     color=ReportConfig.POSITIVE_SENTIMENT_COLOR,
# )

# for index, company in enumerate(good_rating_companies[:3]):
#     ax.annotate(
#         f"{index + 1}º: {company}",
#         xy=(x_annonate, y_position - 3 + 0.6 + index * 0.6),
#         fontsize=font_size_annotate,
#         color=ReportConfig.POSITIVE_SENTIMENT_COLOR,
#     )

# # Top Negative Companies Annotates
# ax.annotate(
#     "Top 3 reviews negativos:",
#     xy=(x_annonate, y_position),
#     fontsize=font_size_annotate,
#     color=ReportConfig.NEGATIVE_SENTIMENT_COLOR,
# )

# for index, company in enumerate(bad_rating_companies[:3]):
#     ax.annotate(
#         f"{index + 1}º: {company}",
#         xy=(x_annonate, y_position + 0.6 + index * 0.6),
#         fontsize=font_size_annotate,
#         color=ReportConfig.NEGATIVE_SENTIMENT_COLOR,
#     )

plt.xlabel("")
plt.xticks([])

plt.ylabel("")

plt.title(
    "Distribuição de Sentimentos de Avaliações no Glassdoor por Empresa",
    fontdict={
        "weight": "bold",
        "size": ReportConfig.CHART_TITLE_FONT_SIZE,
    },
    loc="center",
)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["bottom"].set_visible(False)

positive_patch = plt.Rectangle((0, 0), 1, 1, fc=ReportConfig.POSITIVE_SENTIMENT_COLOR)
negative_patch = plt.Rectangle((0, 0), 1, 1, fc=ReportConfig.NEGATIVE_SENTIMENT_COLOR)
neutral_patch = plt.Rectangle((0, 0), 1, 1, fc=ReportConfig.NEUTRAL_SENTIMENT_COLOR)

# Set the legend with custom labels and handles
plt.legend(
    handles=[positive_patch, negative_patch, neutral_patch],
    labels=["Positivo", "Negativo", "Neutro"],
    title="Sentimento",
)

plt.show()
